# %%
from pyspark.sql.functions import count, col, last
from pyspark.sql.window import Window

# %%
display(dbutils.fs.ls('/databricks-datasets/online_retail'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/online_retail/data-001/</td><td>data-001/</td><td>0</td><td>1725252383763</td></tr></tbody></table></div>

# %%
df=spark.read.csv('/databricks-datasets/online_retail/data-001/data.csv',header=True)

# %%
from pyspark.sql.functions import sum as sum_

null_counts = df.select(
    [sum_(col(c).isNull().cast("int")).alias(c) for c in df.columns]
)

display(null_counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>166</td><td>0</td><td>0</td><td>0</td><td>25281</td><td>0</td></tr></tbody></table></div>

# %%
df.filter(df.Description.isNull()).show()
# Out:
# +---------+---------+-----------+--------+-------------+---------+----------+--------------+
# |InvoiceNo|StockCode|Description|Quantity|  InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+-----------+--------+-------------+---------+----------+--------------+
# |   536414|    22139|       NULL|      56|12/1/10 11:52|        0|      NULL|United Kingdom|
# |   536545|    21134|       NULL|       1|12/1/10 14:32|        0|      NULL|United Kingdom|
# |   536546|    22145|       NULL|       1|12/1/10 14:33|        0|      NULL|United Kingdom|
# |   536547|    37509|       NULL|       1|12/1/10 14:33|        0|      NULL|United Kingdom|
# |   536549|   85226A|       NULL|       1|12/1/10 14:34|        0|      NULL|United Kingdom|
# |   536550|    85044|       NULL|       1|12/1/10 14:34|        0|      NULL|United Kingdom|
# |   536552|    20950|       NULL|       1|12/1/10 14:34|        0|      NULL|United Kingdom|
# |   536553|    37461|       NULL|       3|12/1/10 14:35|        0|      NULL|United Kingdom|
# |   536554|    84670|       NULL|      23|12/1/10 14:35|        0|      NULL|United Kingdom|
# |   536589|    21777|       NULL|     -10|12/1/10 16:50|        0|      NULL|United Kingdom|
# |   536764|   84952C|       NULL|     -38|12/2/10 14:42|        0|      NULL|United Kingdom|
# |   536765|   84952C|       NULL|      19|12/2/10 14:43|        0|      NULL|United Kingdom|
# |   536995|    35951|       NULL|      57|12/3/10 15:29|        0|      NULL|United Kingdom|
# |   536996|    22712|       NULL|     -20|12/3/10 15:30|        0|      NULL|United Kingdom|
# |   536997|    22028|       NULL|     -20|12/3/10 15:30|        0|      NULL|United Kingdom|
# |   536998|    85067|       NULL|      -6|12/3/10 15:30|        0|      NULL|United Kingdom|
# |   536999|    21421|       NULL|     110|12/3/10 15:32|        0|      NULL|United Kingdom|
# |   537000|    21414|       NULL|     -22|12/3/10 15:32|        0|      NULL|United Kingdom|
# |   537001|    21653|       NULL|      -6|12/3/10 15:33|        0|      NULL|United Kingdom|
# |   537002|    21651|       NULL|      70|12/3/10 15:33|        0|      NULL|United Kingdom|
# +---------+---------+-----------+--------+-------------+---------+----------+--------------+
# only showing top 20 rows

# %%
df.filter(df['Stockcode'] == '22139').select('Description').show()
# Out:
# +--------------------+
# |         Description|
# +--------------------+
# |RETROSPOT TEA SET...|
# |                NULL|
# |              amazon|
# |RETROSPOT TEA SET...|
# |                NULL|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |                NULL|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |                NULL|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# +--------------------+
# only showing top 20 rows

# %%
#counting distinct column to map description of null values using stock code
print("Description distinct count:", df.select(col('Description')).distinct().count())
print("stockcode distinct count:", df.select(col('StockCode')).distinct().count())
# Out:
# Description distinct count: 2914
# stockcode distinct count: 2973

# %%
window_spec = Window.partitionBy('Stockcode').orderBy('Stockcode').rowsBetween(Window.unboundedPreceding, Window.currentRow)

# Fill NaN values in 'description' with the last non-null value within the same 'stockcode'
df = df.withColumn('Description', last('Description', True).over(window_spec))

# %%
null_counts = df.select(
    [sum_(col(c).isNull().cast("int")).alias(c) for c in df.columns]
)

display(null_counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>47</td><td>0</td><td>0</td><td>0</td><td>25281</td><td>0</td></tr></tbody></table></div>

# %%
df.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: string (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- CustomerID: string (nullable = true)
#  |-- Country: string (nullable = true)

# %%
df.filter(df['Stockcode'] == '22139').select('Description').show()
# Out:
# +--------------------+
# |         Description|
# +--------------------+
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |              amazon|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# |RETROSPOT TEA SET...|
# +--------------------+
# only showing top 20 rows

# %%
for i in df:
    row_count= df.select(i).count()
    print(i,":", row_count)
# Out:
# Column<'InvoiceNo'> : 65499
# Column<'StockCode'> : 65499
# Column<'Description'> : 65499
# Column<'Quantity'> : 65499
# Column<'InvoiceDate'> : 65499
# Column<'UnitPrice'> : 65499
# Column<'CustomerID'> : 65499
# Column<'Country'> : 65499

# %%
df1= df.select('InvoiceNo', 'Description', 'Quantity', 'UnitPrice', 'StockCode')

# %%
# Adding new column as TotalPrice
df1 = df1.withColumn(
    'TotalPrice', 
    (df1.Quantity * df1.UnitPrice).cast('Float')
).withColumn('Quantity', df1.Quantity.cast('int'))

# Display the DataFrame
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>Description</th><th>Quantity</th><th>UnitPrice</th><th>StockCode</th><th>TotalPrice</th></tr></thead><tbody><tr><td>536370</td><td>INFLATABLE POLITICAL GLOBE </td><td>48</td><td>0.85</td><td>10002</td><td>40.8</td></tr><tr><td>536382</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td>536756</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>0.85</td><td>10002</td><td>0.85</td></tr><tr><td>536863</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>0.85</td><td>10002</td><td>0.85</td></tr><tr><td>536865</td><td>INFLATABLE POLITICAL GLOBE </td><td>5</td><td>1.66</td><td>10002</td><td>8.3</td></tr><tr><td>536876</td><td>INFLATABLE POLITICAL GLOBE </td><td>2</td><td>1.66</td><td>10002</td><td>3.32</td></tr><tr><td>537047</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>0.85</td><td>10002</td><td>0.85</td></tr><tr><td>537227</td><td>INFLATABLE POLITICAL GLOBE </td><td>24</td><td>0.85</td><td>10002</td><td>20.4</td></tr><tr><td>537240</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>537638</td><td>INFLATABLE POLITICAL GLOBE </td><td>5</td><td>1.66</td><td>10002</td><td>8.3</td></tr><tr><td>537642</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>537666</td><td>INFLATABLE POLITICAL GLOBE </td><td>2</td><td>1.66</td><td>10002</td><td>3.32</td></tr><tr><td>537770</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td>537823</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>538069</td><td>INFLATABLE POLITICAL GLOBE </td><td>8</td><td>0.85</td><td>10002</td><td>6.8</td></tr><tr><td>538071</td><td>INFLATABLE POLITICAL GLOBE </td><td>2</td><td>1.66</td><td>10002</td><td>3.32</td></tr><tr><td>538086</td><td>INFLATABLE POLITICAL GLOBE </td><td>10</td><td>0.85</td><td>10002</td><td>8.5</td></tr><tr><td>538093</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td>538167</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td>538196</td><td>INFLATABLE POLITICAL GLOBE </td><td>36</td><td>0.85</td><td>10002</td><td>30.6</td></tr><tr><td>538255</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td>538524</td><td>INFLATABLE POLITICAL GLOBE </td><td>2</td><td>1.66</td><td>10002</td><td>3.32</td></tr><tr><td>538566</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>538593</td><td>INFLATABLE POLITICAL GLOBE </td><td>24</td><td>0.85</td><td>10002</td><td>20.4</td></tr><tr><td>538853</td><td>INFLATABLE POLITICAL GLOBE </td><td>4</td><td>0.85</td><td>10002</td><td>3.4</td></tr><tr><td>538890</td><td>INFLATABLE POLITICAL GLOBE </td><td>3</td><td>0.85</td><td>10002</td><td>2.55</td></tr><tr><td>539322</td><td>INFLATABLE POLITICAL GLOBE </td><td>5</td><td>0.85</td><td>10002</td><td>4.25</td></tr><tr><td>539434</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>539451</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>539595</td><td>INFLATABLE POLITICAL GLOBE </td><td>2</td><td>1.66</td><td>10002</td><td>3.32</td></tr><tr><td>540239</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td>540277</td><td>INFLATABLE POLITICAL GLOBE </td><td>60</td><td>0.85</td><td>10002</td><td>51.0</td></tr><tr><td>540418</td><td>INFLATABLE POLITICAL GLOBE </td><td>1</td><td>1.66</td><td>10002</td><td>1.66</td></tr><tr><td>540732</td><td>INFLATABLE POLITICAL GLOBE </td><td>12</td><td>0.85</td><td>10002</td><td>10.2</td></tr><tr><td ...

# %%
#rename column
df1.select('Description', 'Quantity').withColumnRenamed('Description', 'Desc').groupBy('Desc').sum('Quantity').orderBy('sum(Quantity)', ascending=False).show()
# Out:
# +--------------------+-------------+
# |                Desc|sum(Quantity)|
# +--------------------+-------------+
# |WHITE HANGING HEA...|         8189|
# |PACK OF 72 RETROS...|         6634|
# |WORLD WAR 2 GLIDE...|         6109|
# |HAND WARMER BABUS...|         4060|
# |HEART OF WICKER S...|         4047|
# |JUMBO BAG RED RET...|         3993|
# |SMALL POPCORN HOLDER|         3971|
# |MINI PAINT SET VI...|         3615|
# |ASSORTED COLOUR B...|         3374|
# |FAIRY CAKE FLANNE...|         3365|
# |GROW A FLYTRAP OR...|         2953|
# |PACK OF 12 LONDON...|         2950|
# | BROCADE RING PURSE |         2854|
# |       CHILLI LIGHTS|         2786|
# |CHARLOTTE BAG SUK...|         2722|
# |ANTIQUE SILVER TE...|         2701|
# |GIN + TONIC DIET ...|         2693|
# |REGENCY CAKESTAND...|         2686|
# |RED  HARMONICA IN...|         2669|
# |JAM MAKING SET PR...|         2654|
# +--------------------+-------------+
# only showing top 20 rows
